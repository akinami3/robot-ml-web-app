# %%
# !pip install paho-mqtt
# Out:
# Requirement already satisfied: paho-mqtt in /home/takas/.venv/lib/python3.12/site-packages (2.1.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator>=4.3.2 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.11.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/takas/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/takas/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/takas/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/takas/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/takas/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/takas/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipywidgets]
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install ipycanvas
# Out:
# Collecting ipycanvas
#   Using cached ipycanvas-0.14.1-py2.py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipycanvas) (8.1.8)
# Requirement already satisfied: numpy in /home/takas/.venv/lib/python3.12/site-packages (from ipycanvas) (2.3.3)
# Requirement already satisfied: pillow>=6.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipycanvas) (10.4.0)
# Requirement already satisfied: comm>=0.1.3 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/takas/.venv/lib/python3.12/site-packages (from ipywidgets<9,>=7.6.0->ipycanvas) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (3.0.51)
# Requirement already satisfied: pygments>=2.11.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/takas/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.6.3)
# Requirement already satisfied: wcwidth in /home/takas/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/takas/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/takas/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/takas/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/takas/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (3.0.0)
# Requirement already satisfied: pure-eval in /home/takas/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipycanvas) (0.2.3)
# Using cached ipycanvas-0.14.1-py2.py3-none-any.whl (142 kB)
# Installing collected packages: ipycanvas
# Successfully installed ipycanvas-0.14.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # MQTT初期化

# %%
# --- 1. ライブラリのインストール ---
# !pip install paho-mqtt

import paho.mqtt.client as mqtt
import json
import time

# --- 2. MQTTブローカー設定 ---
BROKER_ADDRESS = "127.0.0.1"  # WSL2の場合はWSLのIPに変更
BROKER_PORT = 1883
AMR_ID = "amr_01"
VELOCITY_TOPIC = f"amr/{AMR_ID}/velocity"
STATUS_TOPIC = f"amr/{AMR_ID}/status"

# --- 3. コールバック関数の定義 ---
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected to MQTT Broker!")
        # Subscribe to Status Topic
        client.subscribe(STATUS_TOPIC)
    else:
        print(f"Failed to connect, return code {rc}")


# --- 4. MQTTクライアント設定 ---
client = mqtt.Client(client_id="jupyter_test")
client.on_connect = on_connect

client.connect(BROKER_ADDRESS, BROKER_PORT, 60)

# --- 5. UnityにVelocityを送信する関数 ---
def send_velocity(linear, angular):
    cmd = {"linear": linear, "angular": angular}
    payload = json.dumps(cmd)
    client.publish(VELOCITY_TOPIC, payload)
    print(f"Published to {VELOCITY_TOPIC}: {payload}")
# Out:
# /tmp/ipykernel_14672/1281368105.py:26: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id="jupyter_test")

# %% [markdown]
# # Velocity Publish
#
# ジョイスティックで操作した速度情報をUnityに送信します。（並進速度、回転速度はテキストボックスで指定可能）

# %%
import ipywidgets as widgets
from ipycanvas import Canvas, hold_canvas
from IPython.display import display

# --- 設定 ---
canvas_size = 200
center = canvas_size // 2
radius = 80
dead_zone = 0.1

max_linear = widgets.FloatText(value=1.0, description='Max Linear:')
max_angular = widgets.FloatText(value=1.0, description='Max Angular:')

canvas = Canvas(width=canvas_size, height=canvas_size)

def draw_joystick(x, y):
    with hold_canvas(canvas):
        canvas.clear()
        canvas.stroke_style = '#888'
        canvas.stroke_circle(center, center, radius)
        canvas.fill_style = '#1e90ff'
        canvas.fill_circle(x, y, 20)

draw_joystick(center, center)


def on_mouse_move(x, y):
    dx = x - center
    dy = y - center

    if (dx**2 + dy**2) > radius**2:
        return

    draw_joystick(x, y)

    nx = dx / radius
    ny = -dy / radius  # 上方向正

    # デッドゾーン処理
    if abs(nx) < dead_zone:
        nx = 0.0
    if abs(ny) < dead_zone:
        ny = 0.0

    # 前後方向 -> linear, 左右方向 -> angular
    linear = ny * max_linear.value
    angular = nx * max_angular.value

    # 後退時に回転の左右を反転
    if linear < 0:
        angular = -angular

    send_velocity(linear, angular)

canvas.on_mouse_move(on_mouse_move)
display(widgets.HBox([max_linear, max_angular]))
display(canvas)
# Out:
# HBox(children=(FloatText(value=1.0, description='Max Linear:'), FloatText(value=1.0, description='Max Angular:…
# Canvas(height=200, width=200)

# %% [markdown]
# # AMR status subscribe
#
# AMRの状態をMQTTで購読し、表示します。

# %%
import ipywidgets as widgets
import subprocess

status_label = widgets.Label(value="Status: 受信待ち...")

def one_time_status():
    try:
        result = subprocess.run([
            "mosquitto_sub",
            "-h", f"{BROKER_ADDRESS}",
            "-p", f"{BROKER_PORT}",
            "-t", f"{STATUS_TOPIC}",
            "-C", "1"  # 1メッセージ受信で終了
        ], stdout=subprocess.PIPE, text=True, timeout=30)
        status = result.stdout.strip()
        if status:
            status_label.value = f"Status: {status}"
        else:
            status_label.value = "Status: 受信なし"
    except Exception as e:
        status_label.value = f"Status: エラー: {e}"

display(status_label)
one_time_status()
# Out:
# Label(value='Status: 受信待ち...')
